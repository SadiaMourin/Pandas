# %%
import pandas as pd

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-37996208-b302-483f-b771-b7253a9292ac" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-37996208-b302-483f-b771-b7253a9292ac">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving weather_data (5).xls to weather_data (5).xls
# {'weather_data (5).xls': b'\xd0\xcf\x11\xe0\xa1\xb1\x1a\xe1\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00>\x00\x03\x00\xfe\xff\t\x00\x06\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x01\x00\x00\x00 \t\x08\x08\x00\x00\x05\x05\x00SI\xcd\x07\xe1\x00\x00\x00\xc1\x00\x02\x00\x00\x00\xbf\x00\x00\x00\xc0\x00\x00\x00\xe2\x00\x00\x00\\\x00p\x00\x06learnp                                                                                                         B\x00\x02\x00\xe4\x04\x9c\x00\x02\x00\x11\x00\x19\x00\x02\x00\x00\x00\x12\x00\x02\x00\x00\x00\x13\x00\x02\x00\x00\x00=\x00\x12\x00\x00\x00\x00\x00(P\x02+8\x00\x00\x00\x00\x00\x01\x00X\x02@\x00\x02\x00\x00\x00\x8d\x00\x02\x00\x00\x00"\x00\x02\x00\x00\x00\x0e\x00\x02\x00\x01\x00\xb7\x01\x02\x00\x00\x00\xda\x00\x02\x00\x00\x001\x00\x16\x00\xdc\x00\x00\x00\x08\x00\x90\x01\x00\x00\x00\x02\x00\x00\x07Calibri1\x00\x16\x00\xdc\x00\x00\x00\x08\x00\x90\x01\x00\x00\x00\x02\x00\x7f\x07Calibri1\x00\x16\x00\xdc\x00\x00\x00\x08\x00\x90\x01\x00\x00\x00\x02\x00\x7f\x07Calibri1\x00\x16\x00\xdc\x00\x00\x00\x08\x00\x90\x01\x00\x00\x00\x02\x00\x7f\x07Calibri1\x00\x16\x00\xdc\x00\x00\x00\x08\x00\x90\x01\x00\x00\x00\x02\x00\x7f\x07Calibri1\x00\x16\x00\xdc\x00\x00\x00\x08\x00\x90\x01\x00\x00\x00\x02\x00\x00\x07Calibri1\x00\x16\x00\xdc\x00\x00\x00\t\x00\x90\x01\x00\x00\x00\x02\x00\x00\x07Calibri1\x00\x16\x00\xdc\x00\x00\x00\x14\x00\x90\x01\x00\x00\x00\x02\x00\x00\x07Calibri1\x00\x16\x00\xdc\x00\x01\x004\x00\xbc\x02\x00\x00\x00\x02\x00\x7f\x07Calibri1\x00\x16\x00\xdc\x00\x01\x00\t\x00\xbc\x02\x00\x00\x00\x02\x00\x00\x07Calibri1\x00\x16\x00\xdc\x00\x02\x00\x17\x00\x90\x01\x00\x00\x00\x02\x00\x00\x07Calibri1\x00\x16\x00\xdc\x00\x00\x00\x11\x00\x90\x01\x00\x00\x00\x02\x00\x00\x07Calibri1\x00\x16\x00,\x01\x01\x006\x00\xbc\x02\x00\x00\x00\x02\x00\x7f\x07Calibri1\x00\x16\x00\x04\x01\x01\x006\x00\xbc\x02\x00\x00\x00\x02\x00\x7f\x07Calibri1\x00\x16\x00\xdc\x00\x01\x006\x00\xbc\x02\x00\x00\x00\x02\x00\x7f\x07Calibri1\x00\x16\x00\xdc\x00\x00\x00>\x00\x90\x01\x00\x00\x00\x02\x00\x00\x07Calibri1\x00\x16\x00\xdc\x00\x00\x004\x00\x90\x01\x00\x00\x00\x02\x00\x7f\x07Calibri1\x00\x16\x00\xdc\x ...

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-3c56e902-d824-4c61-b383-d8e2f362bf2d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3c56e902-d824-4c61-b383-d8e2f362bf2d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving weather_data(5).csv to weather_data(5).csv
# {'weather_data(5).csv': b'day,temperature,windspeed,event\r\n1/1/2017,32,6,Rain\r\n1/4/2017,,7,Sunny\r\n1/5/2017,28,,Snow\r\n1/6/2017,,7,\r\n1/7/2017,32,,Rain\r\n1/8/2017,31,2,Sunny\r\n1/9/2017,,,\r\n1/10/2017,34,8,Cloudy\r\n1/11/2017,40,12,Sunny\r\n'}

# %%
df = pd.read_csv("weather_data(5).csv",parse_dates=['day'])
type(df.day[0])
df
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0    Rain
# 1 2017-01-04          NaN        7.0   Sunny
# 2 2017-01-05         28.0        NaN    Snow
# 3 2017-01-06          NaN        7.0     NaN
# 4 2017-01-07         32.0        NaN    Rain
# 5 2017-01-08         31.0        2.0   Sunny
# 6 2017-01-09          NaN        NaN     NaN
# 7 2017-01-10         34.0        8.0  Cloudy
# 8 2017-01-11         40.0       12.0   Sunny

# %%
df.set_index('day',inplace=True)
df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          NaN        7.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08         31.0        2.0   Sunny
# 2017-01-09          NaN        NaN     NaN
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
new_df = df.fillna(0)
new_df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          0.0        7.0   Sunny
# 2017-01-05         28.0        0.0    Snow
# 2017-01-06          0.0        7.0       0
# 2017-01-07         32.0        0.0    Rain
# 2017-01-08         31.0        2.0   Sunny
# 2017-01-09          0.0        0.0       0
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
new_df = df.fillna({
        'temperature': 0,
        'windspeed': 0,
        'event': 'No Event'
    })
new_df
# Out:
#             temperature  windspeed     event
# day
# 2017-01-01         32.0        6.0      Rain
# 2017-01-04          0.0        7.0     Sunny
# 2017-01-05         28.0        0.0      Snow
# 2017-01-06          0.0        7.0  No Event
# 2017-01-07         32.0        0.0      Rain
# 2017-01-08         31.0        2.0     Sunny
# 2017-01-09          0.0        0.0  No Event
# 2017-01-10         34.0        8.0    Cloudy
# 2017-01-11         40.0       12.0     Sunny

# %%
new_df = df.fillna(method="ffill")
new_df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04         32.0        7.0   Sunny
# 2017-01-05         28.0        7.0    Snow
# 2017-01-06         28.0        7.0    Snow
# 2017-01-07         32.0        7.0    Rain
# 2017-01-08         31.0        2.0   Sunny
# 2017-01-09         31.0        2.0   Sunny
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
new_df = df.fillna(method="bfill")
new_df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04         28.0        7.0   Sunny
# 2017-01-05         28.0        7.0    Snow
# 2017-01-06         32.0        7.0    Rain
# 2017-01-07         32.0        2.0    Rain
# 2017-01-08         31.0        2.0   Sunny
# 2017-01-09         34.0        8.0  Cloudy
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
new_df = df.fillna(method="bfill", axis="columns") # axis is either "index" or "columns"
new_df
# Out:
#            temperature windspeed   event
# day
# 2017-01-01          32         6    Rain
# 2017-01-04           7         7   Sunny
# 2017-01-05          28      Snow    Snow
# 2017-01-06           7         7     NaN
# 2017-01-07          32      Rain    Rain
# 2017-01-08          31         2   Sunny
# 2017-01-09         NaN       NaN     NaN
# 2017-01-10          34         8  Cloudy
# 2017-01-11          40        12   Sunny

# %%
new_df = df.fillna(method="ffill",limit=1)
new_df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04         32.0        7.0   Sunny
# 2017-01-05         28.0        7.0    Snow
# 2017-01-06         28.0        7.0    Snow
# 2017-01-07         32.0        7.0    Rain
# 2017-01-08         31.0        2.0   Sunny
# 2017-01-09         31.0        2.0   Sunny
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
new_df = df.interpolate()
new_df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04         30.0        7.0   Sunny
# 2017-01-05         28.0        7.0    Snow
# 2017-01-06         30.0        7.0     NaN
# 2017-01-07         32.0        4.5    Rain
# 2017-01-08         31.0        2.0   Sunny
# 2017-01-09         32.5        5.0     NaN
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
new_df = df.interpolate(method="time") 
new_df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04         29.0        7.0   Sunny
# 2017-01-05         28.0        7.0    Snow
# 2017-01-06         30.0        7.0     NaN
# 2017-01-07         32.0        4.5    Rain
# 2017-01-08         31.0        2.0   Sunny
# 2017-01-09         32.5        5.0     NaN
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
new_df = df.dropna()
new_df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-08         31.0        2.0   Sunny
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
new_df = df.dropna(how='all')
new_df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          NaN        7.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08         31.0        2.0   Sunny
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
new_df = df.dropna(thresh=1)
new_df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          NaN        7.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08         31.0        2.0   Sunny
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
dt = pd.date_range("01-01-2017","01-11-2017")
idx = pd.DatetimeIndex(dt)
df.reindex(idx)
# Out:
#             temperature  windspeed   event
# 2017-01-01         32.0        6.0    Rain
# 2017-01-02          NaN        NaN     NaN
# 2017-01-03          NaN        NaN     NaN
# 2017-01-04          NaN        7.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08         31.0        2.0   Sunny
# 2017-01-09          NaN        NaN     NaN
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny
